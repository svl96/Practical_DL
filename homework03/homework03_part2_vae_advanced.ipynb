# %% [markdown]
# # Variational Autoencoder (VAE)

# %% [markdown]
# Useful links:
# * Original paper http://arxiv.org/abs/1312.6114
# * Helpful videos explaining the topic
#    * https://www.youtube.com/watch?v=P78QYjWh5sM
#    * http://videolectures.net/deeplearning2015_courville_autoencoder_extension/?q=aaron%20courville

# %% [markdown]
# In this homework we will train an autoencoder to model images of faces. For this we take "Labeled Faces in the Wild" dataset (LFW) (http://vis-www.cs.umass.edu/lfw/), deep funneled version of it. (frontal view of all faces)

# %% [markdown]
# ## Prepare the data

# %%
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Collab setting**

# %%
# if you're running in colab,
# 1. go to Runtime -> Change Runtimy Type -> GPU
# 2. uncomment this:
#!wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py -O lfw_dataset.py

# %%
# The following line fetches you two datasets: images, usable for autoencoder training and attributes.
# Those attributes will be required for the final part of the assignment (applying smiles), so please keep them in mind
from lfw_dataset import fetch_lfw_dataset
data,attrs = fetch_lfw_dataset(dimx=36,dimy=36)

# %%
data = data/255
np.savez("real.npz", Pictures=data.reshape(data.shape[0], 36*36*3))

# %%
data = np.load('real.npz')['Pictures'].reshape((-1, 36, 36, 3))

# %%
data.shape
# Out:
# (13143, 36, 36, 3)

# %%
X_train = data[:10000].reshape((10000, -1))
print(X_train.shape)
X_val = data[10000:].reshape((-1, X_train.shape[1]))
print(X_val.shape)

image_h = data.shape[1]
image_w = data.shape[2]
# Out:
# (10000, 3888)
# (3143, 3888)

# %%
image_h, image_w
# Out:
# (36, 36)

# %% [markdown]
# For simplicity we want all values of the data to lie in the interval $[0,1]$:

# %%
X_train = np.float32(X_train)
X_val = np.float32(X_val)

# %%
def plot_gallery(images, h, w, n_row=3, n_col=6):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.5 * n_col, 1.7 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w, 3)), cmap=plt.cm.gray, vmin=-1, vmax=1, interpolation='nearest')
        plt.xticks(())
        plt.yticks(())

# %%
plot_gallery(X_train, image_h, image_w)

# %%
train = data_utils.TensorDataset(torch.Tensor(X_train), torch.zeros(X_train.shape[0],)) # pseudo labels needed to define TensorDataset
train_loader = data_utils.DataLoader(train, batch_size=100, shuffle=True)

val = data_utils.TensorDataset(torch.Tensor(X_val), torch.zeros(X_val.shape[0],))
val_loader = data_utils.DataLoader(val, batch_size=1, shuffle=False)

# %%
next(iter(train_loader))[0].shape
# Out:
# torch.Size([100, 3888])

# %% [markdown]
# # Autoencoder
#
# Why to use all this complicated formulaes and regularizations, what is the need for variational inference? To analyze the difference, let's first train just an autoencoder on the data:
#
# <img src="Autoencoder_structure.png" alt="Autoencoder">

# %%
dimZ = 64 # Considering face reconstruction task, which size of representation seems reasonable?

# Define the decoder and encoder as networks with one hidden fc-layer
# (that means you will have 2 fc layers in each net)
# Use ReLU for hidden layers' activations
# GlorotUniform initialization for W
# Zero initialization for biases
# It's also convenient to put sigmoid activation on output layer to get nice normalized pics

def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        torch.nn.init.zeros_(m.bias)


class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        
        #TODO
        
        self.encoder = nn.Sequential(
            nn.Linear(36 * 36 * 3, 512), 
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
        ) 
        self.decoder = nn.Sequential(
            nn.Linear(64, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 36 * 36 * 3),
            nn.Sigmoid(),
        )

        self.encoder.apply(init_weights)
        self.decoder.apply(init_weights)

    def forward(self, x):
        
        #TODO
        
        latent_code = self.encoder(x)
        reconstruction = self.decoder(latent_code)
        
        return reconstruction, latent_code

# %%
model = Autoencoder()

# %%
model(next(iter(train_loader))[0])[0].shape
# Out:
# torch.Size([100, 3888])

# %%
# Create MSE loss function
criterion = torch.nn.MSELoss()

autoencoder = Autoencoder().cuda()

# Use Adam optimizer
optimizer = optim.Adam(autoencoder.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50, 80], gamma=0.1)

# %%
def train(model, dataloader, criterion, optimizer, scheduler, num_epoch=32, step=5):
    model.cuda()
    losses = []
    img_progress = []
    for epoch in range(num_epoch):
        for i, (samples, _) in enumerate(dataloader):
            optimizer.zero_grad()
            samples = samples.cuda()
            outputs, _ = model(samples)
            loss = criterion(outputs, samples)
            loss.backward()
            losses.append(loss.detach().cpu().numpy())
            optimizer.step()
            optimizer.zero_grad()
        scheduler.step()
        if (epoch) % step == 0:
            for j, (putin, y) in enumerate(val_loader):
                if j == 2754:
                    putin = putin.cuda()
                    img_progress.append(model(putin)[0].detach())
                    break
        print("#%i, Train loss: %.7f"%(epoch+1,np.mean(losses)),flush=True)
    return losses, img_progress

# %%
# Train your autoencoder
# Visualize progress in reconstruction and loss decay
losses, img_progress = train(autoencoder, train_loader, criterion, optimizer, scheduler, 60)
# Out:
# #1, Train loss: 0.0210547
# #2, Train loss: 0.0176737
# #3, Train loss: 0.0158175
# #4, Train loss: 0.0144266
# #5, Train loss: 0.0133356
# #6, Train loss: 0.0125319
# #7, Train loss: 0.0118504
# #8, Train loss: 0.0112885
# #9, Train loss: 0.0108195
# #10, Train loss: 0.0104353
# #11, Train loss: 0.0101089
# #12, Train loss: 0.0098153
# #13, Train loss: 0.0095742
# #14, Train loss: 0.0093450
# #15, Train loss: 0.0091399
# #16, Train loss: 0.0089524
# #17, Train loss: 0.0087774
# #18, Train loss: 0.0086183
# #19, Train loss: 0.0084683
# #20, Train loss: 0.0083296
# #21, Train loss: 0.0081896
# #22, Train loss: 0.0080610
# #23, Train loss: 0.0079430
# #24, Train loss: 0.0078345
# #25, Train loss: 0.0077344
# #26, Train loss: 0.0076417
# #27, Train loss: 0.0075556
# #28, Train loss: 0.0074754
# #29, Train loss: 0.0074005
# #30, Train loss: 0.0073302
# #31, Train loss: 0.0072643
# #32, Train loss: 0.0072021
# #33, Train loss: 0.0071435
# #34, Train loss: 0.0070880
# #35, Train loss: 0.0070355
# #36, Train loss: 0.0069855
# #37, Train loss: 0.0069379
# #38, Train loss: 0.0068924
# #39, Train loss: 0.0068489
# #40, Train loss: 0.0068073
# #41, Train loss: 0.0067674
# #42, Train loss: 0.0067290
# #43, Train loss: 0.0066921
# #44, Train loss: 0.0066565
# #45, Train loss: 0.0066223
# #46, Train loss: 0.0065891
# #47, Train loss: 0.0065570
# #48, Train loss: 0.0065260
# #49, Train loss: 0.0064959
# #50, Train loss: 0.0064669
# #51, Train loss: 0.0064382
# #52, Train loss: 0.0064106
# #53, Train loss: 0.0063840
# #54, Train loss: 0.0063584
# #55, Train loss: 0.0063337
# #56, Train loss: 0.0063098
# #57, Train loss: 0.0062868
# #58, Train loss: 0.0062645
# #59, Train loss: 0.0062430
# #60, Train loss: 0.0062221

# %%
# Examine the reconstructions
for j, data in enumerate(val_loader, 0):
    inp = Variable(data[0].cuda())
    pred, _ = autoencoder(inp)
    plot_gallery([data[0].numpy(), pred.data.cpu().numpy()], image_h, image_w, n_row=1, n_col=2)
    if (j >= 9):
        break

# %% [markdown]
# Reconstruction is not bad, right?

# %% [markdown]
# # Sampling

# %%
for i, (putin, y) in enumerate(val_loader):
    if i == 2754:
        break
plt.imshow(putin.numpy().reshape((image_w, image_w, 3)))

# %%
plt.figure(figsize=(10, 12))
plt.suptitle('Twin farm')
for i in range(len(img_progress[:20])):
    plt.subplots_adjust(bottom=0.0, left=.1, right=.9, top=.50, hspace=.15)
    plt.subplot(6, 5, 5*(i//5) + i % 5 + 1)
    plt.imshow(img_progress[i].clamp(0,1).data.cpu().numpy().reshape(image_w, image_h, 3))
    plt.title('Epoch = {}'.format(i * 5 + 1))
    plt.axis('off')
plt.tight_layout()

# %%
torch.save(autoencoder.state_dict(), 'autoencoder.pth')

# %% [markdown]
# Let's now sample several latent vectors and perform inference from $z$, reconstruct an image given some random $z$ representations.

# %%
z = (np.random.randn(25, dimZ)*0.5).astype('float32')
output = autoencoder.decoder(Variable(torch.from_numpy(z)).cuda()).clamp(0, 1)
plot_gallery(output.data.cpu().numpy(), image_h, image_w, n_row=5, n_col=5)

# %% [markdown]
# So, if we sample $z$ from normal, whould we eventually generate all possible faces? What do you think?

# %% [markdown]
# # Variational Autoencoder

# %% [markdown]
# Bayesian approach in deep learning considers everything in terms of distributions. Now our encoder generates not just a vector $z$ but posterior ditribution $q(z|x)$. In our case distribution $q$ is Gaussian distibution $N(\mu, \sigma)$ with parameters $\mu$, $\sigma$. Technically, the first difference is that you need to split bottleneck layer in two. One dense layer will generate vector $\mu$, and another will generate vector $\sigma$. Reparametrization trick should be implemented using the **gaussian_sampler** layer, that generates random vetor $\epsilon$ and returns $\mu+\sigma\epsilon \sim N(\mu, \sigma)$ .

# %% [markdown]
# Since our decoder is also a function that generates distribution, we need to do the same splitting for output layer. When testing the model we will look only on mean values, so one of the output will be actual autoencoder output.

# %% [markdown]
# In this homework we only ask for implementation of the simplest version of VAE - one $z$ sample per input. You can consider to sample several outputs from one input and average them.

# %%
# to compare with conventional AE, keep these hyperparameters
# or change them for the values that you used before
dimZ = 64

# define the network
# you can start from https://github.com/pytorch/examples/blob/master/vae/main.py
# or Theano-based examples here https://github.com/Lasagne/Recipes/blob/master/examples/variational_autoencoder/variational_autoencoder.py
# and here https://github.com/y0ast/Variational-Autoencoder/blob/master/VAE.py
# but remember that this is not your ground truth since the data is not MNIST


class SplitLayer(nn.Module):
    def __init__(self, in_featuers, out_features):
        super(SplitLayer, self).__init__()

        self.in_features = in_featuers
        self.out_features = out_features
        self.linear1 = nn.Linear(self.in_features, self.out_features)
        self.linear2 = nn.Linear(self.in_features, self.out_features)
    
    def forward(self, input):
        return self.linear1(input), self.linear2(input)


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        
        #TODO
        self.encoder = nn.Sequential(
            nn.Linear(36 * 36 * 3, 512), 
            nn.ReLU(),
            nn.Linear(512, 256), 
            nn.ReLU(),
        ) 
        self.bottleneck_split = SplitLayer(256, dimZ)

        self.decoder = nn.Sequential(
            nn.Linear(dimZ, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
        )
        self.output_split = SplitLayer(512, 36*36*3)

        self.encoder.apply(init_weights)
        self.decoder.apply(init_weights)
        
        self.bottleneck_split.apply(init_weights)
        self.output_split.apply(init_weights)


        # init_weights(self.mu_layer)
        # init_weights(self.logvar_layer)

    
    def gaussian_sampler(self, mu, logsigma):
        if self.training:
            std = logsigma.exp_()
            eps = Variable(std.data.new(std.size()).normal_())
            return eps.mul(std).add_(mu)
        else:
            return mu

    def forward(self, x):
        
        #TODO
        latent_mu, latent_logsigma = self.bottleneck_split(self.encoder(x))
        latent = self.gaussian_sampler(latent_mu, latent_logsigma)

        reconstruction_mu, reconstruction_logsigma = self.output_split(self.decoder(latent))
        reconstruction_mu = nn.functional.sigmoid(reconstruction_mu)
        reconstruction_logsigma = nn.functional.sigmoid(reconstruction_logsigma)


        return reconstruction_mu, reconstruction_logsigma, latent_mu, latent_logsigma

# %% [markdown]
# And the last, but not least! Place in the code where the most of the formulaes goes to - optimization objective. The objective for VAE has it's own name - variational lowerbound. And as for any lowerbound our intention is to maximize it. Here it is (for one sample $z$ per input $x$):
#
# $$\mathcal{L} = -D_{KL}(q_{\phi}(z|x)||p_{\theta}(z)) + \log p_{\theta}(x|z)$$
#
# Your next task is to implement two functions that compute KL-divergence and the second term - log-likelihood of an output. Here is some necessary math for your convenience:
#
# $$D_{KL} = -\frac{1}{2}\sum_{i=1}^{dimZ}(1+log(\sigma_i^2)-\mu_i^2-\sigma_i^2)$$
# $$\log p_{\theta}(x|z) = \sum_{i=1}^{dimX}\log p_{\theta}(x_i|z)=\sum_{i=1}^{dimX} \log \Big( \frac{1}{\sigma_i\sqrt{2\pi}}e^{-\frac{(\mu_I-x)^2}{2\sigma_i^2}} \Big)=...$$
#
# Don't forget in the code that you are using $\log\sigma$ as variable. Explain, why not $\sigma$?

# %%
def KL_divergence(mu, logsigma):
    return - 0.5 * (1 + 2*logsigma - mu.pow(2) - (2 * logsigma).exp()).sum()

def log_likelihood(x, mu, logsigma):
    den = - (logsigma + np.log(np.sqrt(2 * np.pi)))
    nom = - ((mu - x).pow(2) / (2 *(2 * logsigma).exp()))
    # tt = torch.log(1 / (logsigma.exp() * np.sqrt(2 * np.pi)) * ( -((mu - x)**2) / (2 * (2 * logsigma).exp())))
    # print((den + nom).sum(), tt.sum())
    return ( den + nom ).sum()

def loss_vae(x, mu_gen, logsigma_gen, mu_z, logsigma_z):
    return -log_likelihood(x, mu_gen, logsigma_gen) + KL_divergence(mu_z, logsigma_z)

# %% [markdown]
# And train the model:

# %%
# train your autoencoder
# visualize progress in reconstruction and loss decay

# %%
img = next(iter(train_loader))[0]
outputs = VAE()(img)
loss_vae(img, *outputs)
# Out:
# tensor(630348.0625, grad_fn=<AddBackward0>)

# %%
def train_vae(model, dataloader, criterion, optimizer, scheduler, num_epoch=32, step=5):
    model.cuda()
    losses = []
    img_progress = []
    for epoch in range(num_epoch):
        for i, (samples, _) in enumerate(dataloader):
            optimizer.zero_grad()
            samples = samples.cuda()
            outputs = model(samples)
            loss = criterion(samples, *outputs)
            loss.backward()
            losses.append(loss.detach().cpu().numpy())
            optimizer.step()
            optimizer.zero_grad()
        # scheduler.step()
        if (epoch) % step == 0:
            for j, (putin, y) in enumerate(val_loader):
                if j == 2754:
                    putin = putin.cuda()
                    img_progress.append(model(putin)[0].detach())
                    break
        print("#%i, Train loss: %.2f"%(epoch+1,losses[-1]),flush=True)
    return losses, img_progress

# %%
criterion = loss_vae

autoencoder_vae = VAE().cuda()

# Use Adam optimizer
optimizer = optim.Adam(autoencoder_vae.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50, 80], gamma=0.1)

# %%
losses, img_prog = train_vae(autoencoder_vae, train_loader, criterion, optimizer, scheduler, 60)
# Out:
# #1, Train loss: 371144.53
# #2, Train loss: 365375.56
# #3, Train loss: 363183.50
# #4, Train loss: 362250.69
# #5, Train loss: 361551.59
# #6, Train loss: 361024.53
# #7, Train loss: 360483.88
# #8, Train loss: 360522.47
# #9, Train loss: 360328.03
# #10, Train loss: 360372.06
# #11, Train loss: 360071.81
# #12, Train loss: 360036.38
# #13, Train loss: 360095.84
# #14, Train loss: 359869.78
# #15, Train loss: 359752.44
# #16, Train loss: 359449.84
# #17, Train loss: 359594.53
# #18, Train loss: 359408.56
# #19, Train loss: 359204.28
# #20, Train loss: 359388.00
# #21, Train loss: 359382.25
# #22, Train loss: 359320.44
# #23, Train loss: 359237.91
# #24, Train loss: 359077.81
# #25, Train loss: 359446.09
# #26, Train loss: 359244.19
# #27, Train loss: 359168.50
# #28, Train loss: 359180.28
# #29, Train loss: 358910.88
# #30, Train loss: 359040.97
# #31, Train loss: 358968.78
# #32, Train loss: 358877.22
# #33, Train loss: 358872.34
# #34, Train loss: 359114.00
# #35, Train loss: 358847.56
# #36, Train loss: 358766.25
# #37, Train loss: 358774.94
# #38, Train loss: 358868.41
# #39, Train loss: 358913.97
# #40, Train loss: 358764.38
# #41, Train loss: 358658.19
# #42, Train loss: 358790.50
# #43, Train loss: 358753.09
# #44, Train loss: 358867.00
# #45, Train loss: 358602.34
# #46, Train loss: 358863.72
# #47, Train loss: 358722.81
# #48, Train loss: 358658.66
# #49, Train loss: 358684.09
# #50, Train loss: 358779.06
# #51, Train loss: 358845.75
# #52, Train loss: 358699.09
# #53, Train loss: 358590.88
# #54, Train loss: 358608.78
# #55, Train loss: 358619.19
# #56, Train loss: 358511.97
# #57, Train loss: 358576.19
# #58, Train loss: 358548.59
# #59, Train loss: 358598.34
# #60, Train loss: 358666.00

# %%
val_loader = data_utils.DataLoader(val, batch_size=1, shuffle=True)
autoencoder_vae.eval()
for j, data in enumerate(val_loader, 0):
    input = Variable(data[0].cuda())
    reconstruction_mu, _, lat_mu, lat_sig = autoencoder_vae(input)
    # print((lat_mu.mean(),lat_mu.std(), lat_sig.mean(), lat_sig.std()))
    plot_gallery([data[0].numpy(), reconstruction_mu.data.cpu().numpy()], image_h, image_w, n_row=1, n_col=2)
    if (j >= 9):
        break

# %%
plt.figure(figsize=(10, 12))
plt.suptitle('Twin farm')
for i in range(len(img_prog[:20])):
    plt.subplots_adjust(bottom=0.0, left=.1, right=.9, top=.50, hspace=.15)
    plt.subplot(6, 5, 5*(i//5) + i % 5 + 1)
    plt.imshow(img_prog[i].clamp(0,1).data.cpu().numpy().reshape(image_w, image_h, 3))
    plt.title('Epoch = {}'.format(i * 5 + 1))
    plt.axis('off')
plt.tight_layout()

# %%
torch.save(autoencoder_vae.state_dict(), 'vae.pth')

# %% [markdown]
# And finally sample from VAE.

# %%
# TODO
# Sample some images from the learned distribution
# 1) Sample z ~ N(0,1)
# 2) Sample from N(decoder_mu(z), decoder_sigma(z))

# %%
z = (np.random.normal(0, 1, (25, dimZ)).astype('float32'))
output_mu, output_sigma = autoencoder_vae.output_split(autoencoder_vae.decoder((Variable(torch.from_numpy(z)).cuda())))
output_mu = nn.functional.sigmoid(output_mu).clamp(0, 1).detach().cpu().numpy()
output_sigma = nn.functional.sigmoid(output_sigma).clamp(0, 1).detach().cpu().numpy()
print(output_mu.shape, output_sigma.shape)
plot_gallery((np.random.normal(output_mu, output_sigma, output_mu.shape)*255).astype('uint8'), image_h, image_w, n_row=5, n_col=5)
# Out:
# (25, 3888)(25, 3888)

# %% [markdown]
# Even if in practice you do not see the much difference between AE and VAE, or VAE is even worse, the little bayesian inside you should be jumping for joy right now.
#
# In VAE you can truly sample from image distribution $p(x)$, while in AE there is no easy and correct way to do it.

# %% [markdown]
# ## If you are going to do part 4 (presicion-recall score):

# %%
# using your model, generate face set with len = len(data)
answ = <generated dataset>

# %% [markdown]
# ## Save it ot npz

# %%
np.savez("vae.npz", Pictures=answ)

# %% [markdown]
# # Congrats! and Bonus
#
# If you managed to tune your autoencoders to converge and learn something about the world, now it's time to make fun out of it. As you may have noticed, there are face attributes in dataset. We're interesting in "Smiling" column, but feel free to try others as well! Here is the first task:
#
# 1) Extract the "Smilling" attribute and create a two sets of images: 10 smiling faces and 10 non-smiling ones.
#
# 2) Compute latent representations for each image in "smiling" set and average those latent vectors. Do the same for "non-smiling" set. You have found **"vector representation"** of the "smile" and "no smile" attribute.
#
# 3) Compute the difference: "smile" vector minus "non-smile" vector.
#
# 3) Now check if **"feature arithmetics"** works. Sample a face without smile, encode it and add the diff from p. 3. Check if it works with both AE and VAE.

# %% [markdown]
# <img src="linear.png" alt="linear">

# %%
from lfw_dataset import fetch_lfw_dataset
data,attrs = fetch_lfw_dataset(dimx=36,dimy=36)

# %%
data.shape
# Out:
# (13143, 36, 36, 3)

# %%
data = data/255.

# %%
smiling = data[attrs['Smiling'] > 2.5][:10]

# %%
plt.imshow(smiling[6].reshape((36, 36, 3)), cmap=plt.cm.gray, vmin=-1, vmax=1, interpolation='nearest')

# %%
non_smiling = data[(attrs['Smiling'] < 0.0) & (attrs['Smiling'] > -0.1)][:10]

# %%
plt.imshow(non_smiling[1].reshape((36, 36, 3)), cmap=plt.cm.gray, vmin=-1, vmax=1, interpolation='nearest')

# %%
res_smile, latent_smile = autoencoder(torch.tensor(smiling.reshape((10, -1)).astype('float32')).cuda())
res_non_smile, latent_non_smile = autoencoder(torch.tensor(non_smiling.reshape((10, -1)).astype('float32')).cuda())

# %%
smile_vec = latent_smile.mean(axis=0)
non_smile_vec = latent_non_smile.mean(axis=0)
diff_smile = smile_vec - non_smile_vec

# %%
changed_to_smile = latent_non_smile + diff_smile
generated = autoencoder.decoder(changed_to_smile)

# %%
plot_gallery(res_non_smile.data.cpu().numpy(), image_h, image_w, n_row=2, n_col=5)

# %%
plot_gallery(generated.data.cpu().numpy(), image_h, image_w, n_row=2, n_col=5)
